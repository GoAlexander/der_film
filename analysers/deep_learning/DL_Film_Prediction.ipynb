# %% [markdown]
# ## Loading Datasets

# %%
# Import libraries
# %matplotlib inline
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Reading ratings file
ratings = pd.read_csv('ratings.csv', sep='\t', encoding='latin-1', 
                      usecols=['user_id', 'movie_id', 'user_emb_id', 'movie_emb_id', 'rating'])
max_userid = ratings['user_id'].drop_duplicates().max()
max_movieid = ratings['movie_id'].drop_duplicates().max()

# Reading ratings file
users = pd.read_csv('users.csv', sep='\t', encoding='latin-1', 
                    usecols=['user_id', 'gender', 'zipcode', 'age_desc', 'occ_desc'])

# Reading ratings file
movies = pd.read_csv('movies.csv', sep='\t', encoding='latin-1', 
                     usecols=['movie_id', 'title', 'genres'])

# %% [markdown]
# ## Creating sets

# %%
# Create training set
shuffled_ratings = ratings.sample(frac=1., random_state=42)

# Shuffling users
Users = shuffled_ratings['user_emb_id'].values
print('Users:', Users, ', shape =', Users.shape)

# Shuffling movies
Movies = shuffled_ratings['movie_emb_id'].values
print ('Movies:', Movies, ', shape =', Movies.shape)

# Shuffling ratings
Ratings = shuffled_ratings['rating'].values
print ('Ratings:', Ratings, ', shape =', Ratings.shape)
# Out:
# Users: [5411 5439  367 ...  853 4032  785] , shape = (1000209,)
# Movies: [2682  903 3716 ... 3101 3478 1390] , shape = (1000209,)
# Ratings: [2 5 4 ... 3 5 4] , shape = (1000209,)

# %% [markdown]
# ## Deep Learning Model

# %%
# Import Keras libraries
from keras.callbacks import Callback, EarlyStopping, ModelCheckpoint
# Import CF Model Architecture
from CFModel import CFModel
# Out:
# Using TensorFlow backend.

# %%
# Define constants
K_FACTORS = 100 # The number of dimensional embeddings for movies and users
TEST_USER = 2000 # A random test user (user_id = 2000)

# %% [markdown]
# Compile the model using Mean Squared Error (MSE) as the loss function and the AdaMax learning algorithm.

# %%
# Define model
model = CFModel(max_userid, max_movieid, K_FACTORS)
# Compile the model using MSE as the loss function and the AdaMax learning algorithm
model.compile(loss='mse', optimizer='adamax')
# Out:
# WARNING:tensorflow:From C:\Anaconda3\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py:1290: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# C:\Users\Максим\ML\movielens-master\CFModel.py:28: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   self.add(Merge([P, Q], mode='dot', dot_axes=1))

# %% [markdown]
# ### Train the Model

# %%
# Callbacks monitor the validation loss
# Save the model weights each time the validation loss has improved
callbacks = [EarlyStopping('val_loss', patience=2), 
             ModelCheckpoint('weights.h5', save_best_only=True)]

# Use 30 epochs, 90% training data, 10% validation data 
history = model.fit([Users, Movies], Ratings, nb_epoch=10, validation_split=.1, verbose=2, callbacks=callbacks)
# Out:
# Train on 900188 samples, validate on 100021 samples
# Epoch 1/10
# 701s - loss: 1.0795 - val_loss: 0.9774
# Epoch 2/10
# 686s - loss: 0.9178 - val_loss: 0.8960
# Epoch 3/10
# 687s - loss: 0.8627 - val_loss: 0.8581
# Epoch 4/10
# 691s - loss: 0.8300 - val_loss: 0.8342
# Epoch 5/10
# 698s - loss: 0.8042 - val_loss: 0.8176
# Epoch 6/10
# 695s - loss: 0.7819 - val_loss: 0.8005
# Epoch 7/10
# 691s - loss: 0.7608 - val_loss: 0.7880
# Epoch 8/10
# 696s - loss: 0.7399 - val_loss: 0.7775
# Epoch 9/10
# 702s - loss: 0.7189 - val_loss: 0.7678
# Epoch 10/10
# 700s - loss: 0.6981 - val_loss: 0.7593

# %% [markdown]
# ### Root Mean Square Error
# During the training process above, I saved the model weights each time the validation loss has improved. Thus, I can use that value to calculate the best validation Root Mean Square Error.

# %%
# Show the best validation RMSE
min_val_loss, idx = min((val, idx) for (idx, val) in enumerate(history.history['val_loss']))
print('Minimum RMSE at epoch', '{:d}'.format(idx+1), '=', '{:.4f}'.format(math.sqrt(min_val_loss)))
# Out:
# Minimum RMSE at epoch 10 = 0.8714

# %% [markdown]
# ### Predict the Ratings
# The next step is to actually predict the ratings a random user will give to a random movie. Below I apply the freshly trained deep learning model for all the users and all the movies, using 100 dimensional embeddings for each of them. I also load pre-trained weights from *[weights.h5](https://github.com/khanhnamle1994/movielens/blob/master/weights.h5)* for the model.

# %%
# Use the pre-trained model
trained_model = CFModel(max_userid, max_movieid, K_FACTORS)
# Load weights
trained_model.load_weights('weights.h5')

# %%
# Pick a random test user
users[users['user_id'] == TEST_USER]
# Out:
#       user_id gender zipcode age_desc              occ_desc
# 1999     2000      M   44685    18-24  college/grad student

# %%
# Function to predict the ratings given User ID and Movie ID
def predict_rating(user_id, movie_id):
    #return trained_model.rate(user_id - 1, movie_id - 1)
    return model.rate(user_id - 1, movie_id - 1)

# %% [markdown]
# Show the top 20 movies that user 2000 has already rated, including the *predictions* column showing the values that used 2000 would have rated based on the defined *predict_rating* function.

# %%
user_ratings = ratings[ratings['user_id'] == TEST_USER][['user_id', 'movie_id', 'rating']]
user_ratings['prediction'] = user_ratings.apply(lambda x: predict_rating(TEST_USER, x['movie_id']), axis=1)
user_ratings.sort_values(by='rating', 
                         ascending=False).merge(movies, 
                                                on='movie_id', 
                                                how='inner', 
                                                suffixes=['_u', '_m']).head(20)
# Out:
#     user_id  movie_id  rating  prediction  \
# 0      2000      1639       5    3.624804
# 1      2000      2529       5    3.632480
# 2      2000      1136       5    4.160076
# 3      2000      2321       5    3.832311
# 4      2000      2858       5    4.255318
# 5      2000      2501       5    4.207597
# 6      2000      2804       5    4.236019
# 7      2000      1688       5    3.525112
# 8      2000      1653       5    3.707461
# 9      2000       527       5    4.472422
# 10     2000      1619       5    3.451934
# 11     2000       110       5    3.768412
# 12     2000      1193       5    4.531286
# 13     2000       318       5    4.455616
# 14     2000      1748       5    3.535847
# 15     2000      1923       5    3.743418
# 16     2000      1259       5    4.149250
# 17     2000       595       5    4.038799
# 18     2000      2028       5    3.979524
# 19     2000      1907       5    3.600280
#
#                                      title                        genres
# 0                       Chasing Amy (1997)                 Drama|Romance
# 1                Planet of the Apes (1968)                 Action|Sci-Fi
# 2   Monty Python and the Holy Grail (1974)                        Comedy
# 3                     Pleasantville (1998)                        Comedy
# 4                   American Beauty (1999)                  Comedy|Drama
# 5                       October Sky (1999)                         Drama
# 6                Christmas Story, A (1983)                  Comedy|Drama
# 7                         Anastasia (1997)  Animation|Children's|Musical
# 8                           Gattaca (1997)         Drama|Sci-Fi|Thriller
# 9                  Schindler's List (1993)                     Drama|War
# 10             Seven Years in Tibet (1997)                     Drama|War
# 11                       Braveheart (1995)              Action|Drama|War
# 12  One Flew Over the Cuckoo's Nest (1975)                         Drama
# 13        Shawshank Redemption, The (1994)                         Drama
# 14                        Dark City (1998)     Film-Noir|Sci-Fi|Thriller
# 15     There's Something About Mary (1998)                        Comedy
# 16                      Stand by Me (1986)        Adventure|Comedy|Drama
# 17             Beauty and the Beast (1991)  Animation|Children's|Musical
# 18              Saving Private Ryan (1998)              Action|Drama|War
# 19                            Mulan (1998)          Animation|Children's

# %% [markdown]
# ### Recommend Movies
# List of unrated 20 movies sorted by prediction value for our test user.

# %%
recommendations = ratings[ratings['movie_id'].isin(user_ratings['movie_id']) == False][['movie_id']].drop_duplicates()
recommendations['prediction'] = recommendations.apply(lambda x: predict_rating(TEST_USER, x['movie_id']), axis=1)
recommendations.sort_values(by='prediction',
                          ascending=False).merge(movies,
                                                 on='movie_id',
                                                 how='inner',
                                                 suffixes=['_u', '_m']).head(20)
# Out:
#     movie_id  prediction                                              title  \
# 0       2905    4.887506                                     Sanjuro (1962)
# 1        668    4.682042                             Pather Panchali (1955)
# 2       3030    4.636191                                     Yojimbo (1961)
# 3       3022    4.615102                                General, The (1927)
# 4       2360    4.581410                   Celebration, The (Festen) (1998)
# 5        910    4.552507                            Some Like It Hot (1959)
# 6       1147    4.551263                          When We Were Kings (1996)
# 7        670    4.548893             World of Apu, The (Apur Sansar) (1959)
# 8        669    4.534374                                   Aparajito (1956)
# 9       1204    4.529888                          Lawrence of Arabia (1962)
# 10      2019    4.529125  Seven Samurai (The Magnificent Seven) (Shichin...
# 11      1178    4.520947                              Paths of Glory (1957)
# 12      3306    4.511634                                 Circus, The (1928)
# 13       912    4.506579                                  Casablanca (1942)
# 14      2731    4.505169     400 Blows, The (Les Quatre cents coups) (1959)
# 15       951    4.502432                             His Girl Friday (1940)
# 16       922    4.496959      Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)
# 17      1207    4.492234                       To Kill a Mockingbird (1962)
# 18      2203    4.490530                           Shadow of a Doubt (1943)
# 19      1361    4.490085  Paradise Lost: The Child Murders at Robin Hood...
#
#                   genres
# 0       Action|Adventure
# 1                  Drama
# 2   Comedy|Drama|Western
# 3                 Comedy
# 4                  Drama
# 5           Comedy|Crime
# 6            Documentary
# 7                  Drama
# 8                  Drama
# 9          Adventure|War
# 10          Action|Drama
# 11             Drama|War
# 12                Comedy
# 13     Drama|Romance|War
# 14                 Drama
# 15                Comedy
# 16             Film-Noir
# 17                 Drama
# 18    Film-Noir|Thriller
# 19           Documentary
